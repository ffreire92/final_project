# %% [raw]
# !pip install covid

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pylab as plt
from covid import Covid
import json

# %%
covid = Covid()
covid.get_data()
# Out:
# [{'id': '180',
#   'country': 'US',
#   'confirmed': 33486101,
#   'active': None,
#   'deaths': 600285,
#   'recovered': None,
#   'latitude': 40.0,
#   'longitude': -100.0,
#   'last_update': 1623835273000},
#  {'id': '80',
#   'country': 'India',
#   'confirmed': 29633105,
#   'active': 865432,
#   'deaths': 379573,
#   'recovered': 28388100,
#   'latitude': 20.593684,
#   'longitude': 78.96288,
#   'last_update': 1623835273000},
#  {'id': '24',
#   'country': 'Brazil',
#   'confirmed': 17533221,
#   'active': 1522570,
#   'deaths': 490696,
#   'recovered': 15519955,
#   'latitude': -14.235,
#   'longitude': -51.9253,
#   'last_update': 1623835273000},
#  {'id': '63',
#   'country': 'France',
#   'confirmed': 5806256,
#   'active': 5295304,
#   'deaths': 110692,
#   'recovered': 400260,
#   'latitude': 46.2276,
#   'longitude': 2.2137,
#   'last_update': 1623835273000},
#  {'id': '179',
#   'country': 'Turkey',
#   'confirmed': 5342028,
#   'active': 82127,
#   'deaths': 48879,
# ...

# %%
df = pd.json_normalize(covid.get_data())
df = df.drop(columns = ['id', 'latitude', 'longitude', 'last_update'], axis = 1)

# %%
df.country.unique()
# Out:
# array(['US', 'India', 'Brazil', 'France', 'Turkey', 'Russia',
#        'United Kingdom', 'Italy', 'Argentina', 'Colombia', 'Spain',
#        'Germany', 'Iran', 'Poland', 'Mexico', 'Ukraine', 'Peru',
#        'Indonesia', 'South Africa', 'Netherlands', 'Czechia', 'Chile',
#        'Canada', 'Philippines', 'Iraq', 'Sweden', 'Romania', 'Belgium',
#        'Pakistan', 'Portugal', 'Israel', 'Bangladesh', 'Hungary', 'Japan',
#        'Jordan', 'Serbia', 'Switzerland', 'Malaysia', 'Austria', 'Nepal',
#        'United Arab Emirates', 'Lebanon', 'Morocco', 'Saudi Arabia',
#        'Kazakhstan', 'Ecuador', 'Bulgaria', 'Greece', 'Bolivia',
#        'Belarus', 'Paraguay', 'Slovakia', 'Panama', 'Tunisia', 'Croatia',
#        'Georgia', 'Costa Rica', 'Uruguay', 'Azerbaijan', 'Kuwait',
#        'West Bank and Gaza', 'Dominican Republic', 'Denmark', 'Lithuania',
#        'Ethiopia', 'Egypt', 'Guatemala', 'Ireland', 'Bahrain', 'Slovenia',
# ...
